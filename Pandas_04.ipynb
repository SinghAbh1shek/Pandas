# %% [markdown]
# <a href="https://colab.research.google.com/github/SinghAbh1shek/Pandas/blob/main/Pandas_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('/content/purchases_lyst1748071489995.xlsx')
data
# Out:
#       Unnamed: 0    id           purch_date  customer_num  product_num  \
# 0              0     1  2019-01-03 00:00:00           823           27
# 1              1     2  2019-01-03 00:00:00           606           28
# 2              2     3  2019-01-03 00:00:00           955            9
# 3              3     4  2019-01-03 00:00:00           577           19
# 4              4     5  2019-01-03 00:00:00           429            8
# ...          ...   ...                  ...           ...          ...
# 5995        5995  5996           06/20/2019           893           33
# 5996        5996  5997           06/20/2019           566           23
# 5997        5997  5998           06/20/2019           114           19
# 5998        5998  5999           06/20/2019           404           11
# 5999        5999  6000           06/20/2019            88           57
#
#       amount     paid
# 0         12  $568.92
# 1         14  $395.36
# 2         17  $510.17
# ...

# %%
data.drop(columns='Unnamed: 0', inplace=True)

# %%
data.head()
# Out:
#    id           purch_date  customer_num  product_num  amount     paid
# 0   1  2019-01-03 00:00:00           823           27      12  $568.92
# 1   2  2019-01-03 00:00:00           606           28      14  $395.36
# 2   3  2019-01-03 00:00:00           955            9      17  $510.17
# 3   4  2019-01-03 00:00:00           577           19       3   $68.49
# 4   5  2019-01-03 00:00:00           429            8      18  $759.42

# %% [markdown]
# convert purch_date->datetime

# %%
data['purch_date'] = pd.to_datetime(data['purch_date'])
data.dtypes
# Out:
# id                       int64
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                    object
# dtype: object

# %%
data.head()
# Out:
#    id purch_date  customer_num  product_num  amount     paid
# 0   1 2019-01-03           823           27      12  $568.92
# 1   2 2019-01-03           606           28      14  $395.36
# 2   3 2019-01-03           955            9      17  $510.17
# 3   4 2019-01-03           577           19       3   $68.49
# 4   5 2019-01-03           429            8      18  $759.42

# %% [markdown]
# convert id-> object

# %%
data['id'] = data['id'].astype(object)
data.dtypes
# Out:
# id                      object
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                    object
# dtype: object

# %% [markdown]
# convert paid-> float

# %%
data['paid'] = data['paid'].astype(float) #we can't convert that its contain string/object
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-4109964515> in <cell line: 0>()
# ----> 1 data['paid'] = data['paid'].astype(float)
#       2 data.dtypes
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
# paid -> data preprocess and then only we can do the type conversion

data['paid'] = data['paid'].str.replace('[\$,]', '', regex=True)    #Its remove the $ and , form data['paid']
data.head()
# Out:
#   id purch_date  customer_num  product_num  amount    paid
# 0  1 2019-01-03           823           27      12  568.92
# 1  2 2019-01-03           606           28      14  395.36
# 2  3 2019-01-03           955            9      17  510.17
# 3  4 2019-01-03           577           19       3   68.49
# 4  5 2019-01-03           429            8      18  759.42

# %%
data['paid'] = data['paid'].astype(float)
data.dtypes
# Out:
# id                      object
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                   float64
# dtype: object
